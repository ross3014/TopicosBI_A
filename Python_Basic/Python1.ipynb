# %% [markdown]
# # Python for Big Data
#
# 1. Variables
# 2. String
# 3. Function print
# 4. Booleanos y Condicionales
# 5. Loops
# 6. Functions
# 7. Manejo de excepciones

# %% [markdown]
# # 1. Variables

# %%
# Variables
resultado=0

# %%
# Declarando variables
monto_deuda=1000
moneda="soles  "

# %%
# mostrar variables
monto_deuda
# Out:
# 1000

# %%
moneda=0

# %%
# Interactuar con el usuario
monto_interes=int(input("Ingrese el monto del interes: "))

# %%
# operando con variables
resultado=monto_deuda*4
resultado
# Out:
# 4000

# %%
# Tipo de variable
type(monto_deuda)
# Out:
# int

# %%
type(moneda)
# Out:
# str

# %%
# operar variables
4*resultado
# Out:
# 16000

# %%
# cambiando el tipo de variable
str_monto_deuda=str(monto_deuda)
str_monto_deuda
# Out:
# '1000'

# %%
int_monto_deuda=int(str_monto_deuda)
int_monto_deuda
# Out:
# 1000

# %% [markdown]
# # 2. String

# %%
# Concatenar
'Ho' + 'la'
# Out:
# 'Hola'

# %%
# Comillas simples o dobles
text_1="Mi primer mensaje"
text_2='Mi segundo mensaje'

# %%
text_1
# Out:
# 'Mi primer mensaje'

# %%
text_2
# Out:
# 'Mi segundo mensaje'

# %%
# Comillas triples
consulta = """
select * from users
where ID = 8
group by ADMIN
"""

# %%
consulta
# Out:
# '\nselect * from users\nwhere ID = 8\ngroup by ADMIN\n'

# %%
# oPERACIONES CON sTRING
cadena_1="hola mundo"
cadena_2="5"
cadena_3="cinco"

# %%
cadena_1.capitalize()
# Out:
# 'Hola mundo'

# %%
cadena_3.upper()
# Out:
# 'CINCO'

# %%
cadena_3.lower()
# Out:
# 'cinco'

# %%
cadena_1.title()
# Out:
# 'Hola Mundo'

# %%
#dividir una cadena
cadena_1.split()
# Out:
# ['hola', 'mundo']

# %%
#contar cuantas o tiene
cadena_1.count("o")
# Out:
# 2

# %%
# longitud de uan cadena
len(cadena_1)
# Out:
# 10

# %%
# quitar letra string
cadena_1.split("m")
# Out:
# ['hola ', 'undo']

# %%
# limpiando extremos de un string
cadena_4='(Hola Mundo),'
cadena_4.strip()
# Out:
# '(Hola Mundo),'

# %%
cadena_4.strip('(), ')
# Out:
# 'Hola Mundo'

# %%
# Reemplazar string
cadena_5 ='Hola Mundo' 
cadena_5.replace('Mundo','Hi')
# Out:
# 'Hola Hi'

# %%
cadena_5.index('o')
# Out:
# 1

# %%
cadena_5.index('o',6)
# Out:
# 9

# %%
cadena_5[4]
# Out:
# ' '

# %%
cadena_5[-2]
# Out:
# 'd'

# %%
cadena_5[2:-4]
# Out:
# 'la M'

# %%
#invirtiendo la cadena
cadena_5[::-1]
# Out:
# 'odnuM aloH'

# %%
#llamada a una cadena
cadena_4.strip('(), ').upper().split()
# Out:
# ['HOLA', 'MUNDO']

# %%
#python  f-string
nombre='Rosselly'
curso='Topicos Especiales en Inteligencia de Negocios'
f'hola {nombre} este es el curso de {curso}'
# Out:
# 'hola Rosselly este es el curso de Topicos Especiales en Inteligencia de Negocios'

# %%
string_1='Hola mundo'
string_2='5'
string_3='cinco'

# %%
string_1.isdigit()
# Out:
# False

# %%
string_2.isdigit()
# Out:
# True

# %%
string_3.isalpha()
# Out:
# True

# %%
import string
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %% [markdown]
# #3. Funcion Print

# %%
print(string_1)
# Out:
# Hola mundo

# %%
print(type(string_1))
# Out:
# <class 'str'>

# %%
print(type(5))
# Out:
# <class 'int'>

# %%
print('Mi nombre es:',nombre)
print(f'Mi nombre es: {nombre}')
# Out:
# Mi nombre es: Rosselly
# Mi nombre es: Rosselly

# %%
print("Los datos del curso son: \nCurso \t\t:Topicos Especiales en Inteligencia de Negocios\nCiclo \t\t:Sexto\nTipo Curso: \t: Electivo")
# Out:
# Los datos del curso son:
# Curso 		:Topicos Especiales en Inteligencia de Negocios
# Ciclo 		:Sexto
# Tipo Curso: 	: Electivo

# %%
final_page = False
print(type(final_page))
# Out:
# <class 'bool'>

# %%
if final_page:
    print('Final de la pagina')
else:
    print('Sigue leyendo')
# Out:
# Sigue leyendo

# %%
#operadores logicos
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
#Comparacion
1 < 'uno'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 #Comparacion
# ----> 2 1 < 'uno'
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# #5. Loops

# %%
for letra in 'Hola Mundo':
    print(letra)
# Out:
# H
# o
# l
# a
#
# M
# u
# n
# d
# o

# %%
my_string ='Hola a Todos'
palabras = my_string.split()
print(f'palabras:{palabras}')
# Out:
# palabras:['Hola', 'a', 'Todos']

# %%
for palabra in palabras:
    print(palabra)
# Out:
# Hola
# a
# Todos

# %%
for idx, palabra in enumerate(palabras):
    print(idx,palabra)
# Out:
# 0 Hola
# 1 a
# 2 Todos

# %%
for idx, palabra in enumerate(palabras,1):
    print(idx,palabra)
# Out:
# 1 Hola
# 2 a
# 3 Todos

# %%
#trabajando con While loops
max_intentos=5
intento = 1
while intento <= max_intentos:
    print(f'El numero de intento {intento}')
    intento +=1
# Out:
# El numero de intento 1
# El numero de intento 2
# El numero de intento 3
# El numero de intento 4
# El numero de intento 5

# %%
print('Ya me voy')
# Out:
# Ya me voy

# %%
len('Aprobaré el curso')

# %%
#Creando funciones
def saluda():
    print('Hola')

# %%
saluda()
# Out:
# Hola

# %%
def saluda(nombre):
    print(f'Hola,{nombre}')

# %%
saluda('Juan come Pan')
# Out:
# Hola,Juan come Pan

# %%
def bienvenido(nombre,lugar):
    print(f'Bienvenido {nombre}, llegaste a {lugar}')

# %%
bienvenido('Jaime','Cuzco')
# Out:
# Bienvenido Jaime, llegaste a Cuzco

# %%
#Funcion que retorna un valor
def sumar(a,b):
    return a+b

# %%
resultado=sumar(9,7)
print(resultado)
# Out:
# 16

# %%
#reutilizando funcion en una condicion
if sumar(9,7) %2==0:
    print('La suma es un numero par')
else:
    print('La suma es un numero impar')
# Out:
# La suma es un numero par
